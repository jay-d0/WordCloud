# %%
from NewWordCloud import make_wcld
make_wcld('힙하다', print_check_time=True)
# Out:
# 시작시간 :  2022-08-29 00:39:40.211842
# 종료시간 : 2022-08-29 00:43:37.053821
# 소요시간 :  0:03:56.841979

# %%
from NewWordCloud import make_wcld
make_wcld('뉴진스', speed='fast', font='subtitles', mask='apple', print_check_time=True)
# Out:
# 시작시간 :  2022-08-29 00:59:20.593118

# %%
from NewWordCloud import make_wcld

# %%
from NewWordCloud import make_wcld
make_wcld('영화', save_path='wordcloud/시연', speed='fast',
          font='subtitles', mask='apple', print_check_time=False)

# %%
make_wcld('와이키키', speed='fast')

# %%
make_wcld('아바타2')

# %%
make_wcld('용아맥', speed='fast')
